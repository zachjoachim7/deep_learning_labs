# %% [markdown]
# <a href="https://colab.research.google.com/github/zachjoachim7/deep_learning_labs/blob/main/DL_Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.6.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (4.66.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.31.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.16.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (0.1.99)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.6.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.16.0
#     Uninstalling torchtext-0.16.0:
#       Successfully uninstalled torchtext-0.16.0
# Successfully installed torchtext-0.6.0
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 44.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# --2024-03-02 22:03:04--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.06s
#
# 2024-03-02 22:03:04 (136 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2024-03-02 22:03:04--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.06s
#
# 2024-03-02 22:03:05 (128 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))

class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)

class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))

def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)



class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)

class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)

    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)

def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'

    # scores = QK^T/scale
    scores = torch.bmm(query, torch.transpose(key, 1, 2))
    scale = query.shape[2]
    scores = scores / scale**.5
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)

    # output = softmax(scores)(V)
    soft_max = F.softmax(scores, 2)

    return torch.bmm(soft_max, value)

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.h = h
        self.d_model = d_model
        self.d_k = d_model // h
        self.d_v = d_model // h

        W_q = nn.Linear(d_model, self.d_k)
        W_k = nn.Linear(d_model, self.d_k)
        W_v = nn.Linear(d_model, self.d_v)
        self.W_o = nn.Linear(d_model, d_model)
        # Make an attention head (linear layers for q, k, and v)

        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.W_qh = clones(W_q, h)
        self.W_kh = clones(W_k, h)
        self.W_vh = clones(W_v, h)
        # etc.

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        # etc.
      attention_heads = [attention(self.W_qh[i](query), self.W_kh[i](key), self.W_vh[i](value), mask) for i in range(self.h)]
      concat_vals = torch.cat(attention_heads, 2)
      output = self.W_o(concat_vals)
      return output

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)],
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()

        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy

        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn),
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)

    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()

    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask


global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None

    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD,
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt

    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)),
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)

        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)


def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg,
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter),
                  model,
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.633439 Tokens per Sec: 1060.476929
# Epoch Step: 51 Loss: 5.908243 Tokens per Sec: 12284.073242
# Epoch Step: 101 Loss: 5.624955 Tokens per Sec: 12977.671875
# Epoch Step: 151 Loss: 5.413150 Tokens per Sec: 11105.284180
# Epoch Step: 201 Loss: 5.050286 Tokens per Sec: 12721.098633
# Epoch Step: 251 Loss: 5.019643 Tokens per Sec: 12400.725586
# Epoch Step: 301 Loss: 4.960227 Tokens per Sec: 11152.602539
# Epoch Step: 351 Loss: 4.582519 Tokens per Sec: 12834.275391
# Epoch Step: 401 Loss: 5.191968 Tokens per Sec: 13073.201172
# Epoch Step: 451 Loss: 4.730885 Tokens per Sec: 12603.356445
# Epoch Step: 501 Loss: 4.670133 Tokens per Sec: 11346.204102
# Epoch Step: 551 Loss: 4.464395 Tokens per Sec: 13074.899414
# Epoch Step: 1 Loss: 2.427866 Tokens per Sec: 5785.454102
# Epoch Step: 51 Loss: 3.012468 Tokens per Sec: 11128.022461
# Epoch Step: 101 Loss: 2.396073 Tokens per Sec: 13295.992188
# Epoch Step: 151 Loss: 2.721135 Tokens per Sec: 12790.184570
# Epoch Step: 201 Loss: 2.062303 Tokens per Sec: 11405.058594
# Epoch Step: 251 Loss: 1.954719 Tokens per Sec: 13184.170898
# Epoch Step: 301 Loss: 2.817343 Tokens per Sec: 12964.429688
# Epoch Step: 351 Loss: 3.282456 Tokens per Sec: 12419.241211
# Epoch Step: 401 Loss: 2.619676 Tokens per Sec: 11623.139648
# Epoch Step: 451 Loss: 3.004845 Tokens per Sec: 13013.332031
# Epoch Step: 501 Loss: 2.712561 Tokens per Sec: 12793.000000
# Epoch Step: 551 Loss: 2.472402 Tokens per Sec: 10943.932617
# Epoch Step: 601 Loss: 1.772253 Tokens per Sec: 13036.213867
# Epoch Step: 651 Loss: 2.485487 Tokens per Sec: 12649.190430
# Epoch Step: 701 Loss: 2.501998 Tokens per Sec: 10786.142578
# Epoch Step: 751 Loss: 2.164044 Tokens per Sec: 12698.533203
# Epoch Step: 801 Loss: 2.562750 Tokens per Sec: 12100.100586
# Epoch Step: 851 Loss: 2.111945 Tokens per Sec: 11486.153320
# Epoch Step: 901 Loss: 2.559433 Tokens per Sec: 11702.820312
# Epoch Step: 951 Loss: 2.094021 Tokens per Sec: 12300.455078
# Epoch Step: 1001 Loss: 2.357699 Tokens per Sec: 12948.372070
# Epoch Step: 1051 Loss: 2.068971 Tokens per Sec: 10892.856445
# Epoch Step: 1101 Loss: 2.443250 Tokens per Sec: 12341.256836
# Epoch Step: 1151 Loss: 2.112023 Tokens per Sec: 12597.022461
# Epoch Step: 1201 Loss: 1.969930 Tokens per Sec: 11188.936523
# Epoch Step: 1251 Loss: 1.765304 Tokens per Sec: 12961.983398

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask,
                           Variable(ys),
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys,
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)

for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask,
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()

    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	de Jesús
# Translation:	Jesus Christ of Christ
# Target:		See what God hath done .
#
# Spanish:	Octubre de 2016
# Translation:	October 2016
# Target:		October 2016
#
# Spanish:	Libro de Mormón
# Translation:	Book of Mormon
# Target:		Book of Mormon
#
# Spanish:	El poder del sacerdocio
# Translation:	The Power of the Priesthood
# Target:		Priesthood Power
#
# Spanish:	Alma entendió eso .
# Translation:	Alma found this .
# Target:		Alma understood this .
#
# Spanish:	Sesión General de Mujeres
# Translation:	Women ’s General Women
# Target:		General Women ’s Session
#
# Spanish:	Hay muchos más .
# Translation:	There are many more .
# Target:		There are many more .
#
# Spanish:	<unk> de energía .
# Translation:	They will take the energy .
# Target:		I had an <unk> of energy .
#
# Spanish:	Oposición en todas las cosas
# Translation:	Think about all things
# Target:		Opposition in All Things
#
# Spanish:	Doctrina y Convenios 29:36 .
# Translation:	Doctrine and Covenants 45:44 .
# Target:		Doctrine and Covenants 29:36 .
#
# Spanish:	Doctrina y Convenios <unk> .
# Translation:	Doctrine and Covenants 45:44 .
# Target:		Doctrine and Covenants <unk> .
#
# Spanish:	Doctrina y Convenios 122:9 .
# Translation:	Doctrine and Covenants 76:59 .
# Target:		Doctrine and Covenants 122:9 .
#
# Spanish:	si tuviese esa habilidad ,
# Translation:	He had been the ability ,
# Target:		If that were mine to choose ,
#
# Spanish:	Departamento de Auditorías de la Iglesia
# Translation:	Church Auditing Department Report
# Target:		Church Auditing Department
#
# Spanish:	Por el élder D. Todd Christofferson
# Translation:	By Elder D. Todd Christofferson
# Target:		By Elder D. Todd Christofferson
#
# Spanish:	¡ Me encanta esa doctrina !
# Translation:	I love that doctrine !
# Target:		I love that doctrine !
#
# Spanish:	Todo era nuevo para mí .
# Translation:	All was new for me .
# Target:		Everything was new to me .
#
# Spanish:	Seguir adelante con fe en Cristo
# Translation:	Following Faith in Christ
# Target:		Press Forward with Faith in Christ
#
# Spanish:	<unk> 11:1 ; Alma 32:21 .
# Translation:	They will be opened .
# Target:		See Hebrews 11:1 ; Alma 32:21 .
#
# Spanish:	<unk> del <unk> la hermana Costa
# Translation:	Let ’s illustrate the sister ’s lamp
# Target:		Elder and Sister Costa ’s wedding day
#
# Spanish:	Atrévete a lo correcto aunque solo estés
# Translation:	Let us be able to be alone .
# Target:		Dare to Stand Alone
#
# Spanish:	Por el élder Claudio R. M. Costa
# Translation:	By Elder M. Dibb
# Target:		By Elder Claudio R. M. Costa
#
# Spanish:	Véase Mateo <unk> ; Mosíah 2:17 .
# Translation:	See Matthew 28:6 ; Mosiah 3:19 .
# Target:		See Matthew <unk> ; Mosiah 2:17 .
#
# Spanish:	Posteriormente , sus padres se divorciaron .
# Translation:	Later , his parents are divorced .
# Target:		Later on , her parents divorced .
#
# Spanish:	Presidente del Quórum de los Doce Apóstoles
# Translation:	President of the Quorum of the Twelve Apostles
# Target:		President of the Quorum of the Twelve Apostles
#
# Spanish:	Tenemos muchísima información a nuestro alcance .
# Translation:	We have been available to our most .
# Target:		So much information of man is now at our fingertips .
#
# Spanish:	He allí la tierra santa y pura ,
# Translation:	I have seen the earth and pure and pure , pure and pure and pure and pure love ,
# Target:		A land holy and pure ,
#
# Spanish:	Primera oración : Élder Anthony D. Perkins .
# Translation:	Invocation : Elder D. Porter , please manifest it .
# Target:		Invocation : Elder Anthony D. Perkins .
#
# Spanish:	Medité sobre mi vida hasta ese punto .
# Translation:	I pondered my life until it point .
# Target:		I pondered my life to that point .
#
# Spanish:	Me bauticé con mis amigos en 1972 .
# Translation:	I was baptized with my friends in 1972 .
# Target:		I was baptized with my friends in 1972 .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the sacred name of Jesus Christ , amen .
#
# Spanish:	Primera Consejera de la Presidencia General de la Primaria
# Translation:	First Counselor in the Primary General Presidency
# Target:		First Counselor , Primary General Presidency
#
# Spanish:	El espíritu se nutre de la verdad eterna .
# Translation:	The spirit is given to eternal truth .
# Target:		The spirit is nurtured by eternal truth .
#
# Spanish:	¿ Recuerdan el <unk> que Él les dio ?
# Translation:	Do you remember the energy that He gave you ?
# Target:		Do you remember the nickname He gave them ?
#
# Spanish:	Lo mismo sucede con los hermanos del sacerdocio .
# Translation:	The same is the brethren of the priesthood .
# Target:		And no less the brethren of the priesthood .
#
# Spanish:	Tenemos algunos jóvenes maravillosos en la Iglesia ” .
# Translation:	We have some young women in the Church . ”
# Target:		We have some wonderful youth in the Church . ”
#
# Spanish:	En el sagrado nombre de Jesucristo . Amén .
# Translation:	In the sacred name of Jesus Christ , amen .
# Target:		In the sacred name of Jesus Christ , amen .
#
# Spanish:	Pueden orar cuando el coro vaya a cantar .
# Translation:	You can pray when the choir will sing .
# Target:		You can pray as the choir is about to sing .
#
# Spanish:	Informe del Departamento de Auditorías de la Iglesia , 2011
# Translation:	Church Auditing Department Report , 2011
# Target:		Church Auditing Department Report , 2011
#
# Spanish:	Sus ojos se llenaron de lágrimas por tercera vez .
# Translation:	His eyes were filled with tears for the third time .
# Target:		Tears filled his eyes a third time .
#
# Spanish:	En emergencias , las oraciones y bendiciones vienen primero .
# Translation:	In a phone , prayers , and the first blessings come .
# Target:		In emergencies , prayers and blessings come first .
#
# Spanish:	pero muchos de nosotros todavía estamos perdiendo las bendiciones .
# Translation:	But many of us still are still the blessings .
# Target:		But many of us are still missing the blessings .
#
# Spanish:	Menos conocido es el servicio humanitario de nuestra Iglesia .
# Translation:	We will have been the Internet in our Church .
# Target:		Less well known is our Church ’s global humanitarian service .
#
# Spanish:	Este sencillo verso nos implora que elijamos nuestras prioridades :
# Translation:	This simple emotion we will ask our priorities :
# Target:		This simple <unk> begs us to do some priority sifting :
#
# Spanish:	<unk> “ la llave del conocimiento de Dios ” .
# Translation:	He will “ take the key to the knowledge of God . ”
# Target:		It holds “ even the key of the knowledge of God . ”
#
# Spanish:	Excepto recitar el Padrenuestro , yo no sabía orar .
# Translation:	You will tell the Lord , I did not know .
# Target:		Other than saying the Lord ’s Prayer , I did n’t really know how to pray .
#
# Spanish:	mientras más fuerte el viento , más fuerte el árbol .
# Translation:	As the stronger , the most strong , the tree .
# Target:		The stronger wind , the stronger trees .
#
# Spanish:	¿ En alguna ocasión te han ministrado ángeles ? ” .
# Translation:	Have you are you are you to be angels ? ”
# Target:		Have you ever had angels minister to you ? ”
#
# Spanish:	Otros sagrados propósitos básicos del día de reposo no cambiaron .
# Translation:	Others of the Sabbath day the Sabbath day .
# Target:		Other basic sacred purposes of the Sabbath remained unchanged .
#
# Spanish:	Sean un ejemplo ; sean una influencia para bien ” .
# Translation:	Be a example . ”
# Target:		Be an example ; be an influence for good . ”
#
# Spanish:	¿ Dónde se encontraban las multitudes que José había mencionado ?
# Translation:	Where were they were the people who had mentioned ?
# Target:		Where were the crowds of people that Joseph had mentioned ?
#
# Spanish:	Dios desea que tengamos gozo y que sintamos Su amor .
# Translation:	God wants us to have joy and feel His love .
# Target:		God wants us to have joy and to feel His love .
#
# Spanish:	Él creó este mundo bajo la dirección de Su Padre .
# Translation:	He created this world under the direction of His Father .
# Target:		Under the direction of His Father , He created this world .
#
# Spanish:	“ Entonces ” , dijo , “ sigan adelante ” .
# Translation:	“ Then , ” said , “ Please follow . ”
# Target:		“ Well then , ” he said , “ drive on . ”
#
# Spanish:	No deben tener ninguna duda acerca de su valor individual .
# Translation:	There must not have no doubt about your own courage .
# Target:		Let there be no question in your mind about your value as an individual .
#
# Spanish:	Cuarto : Invitar a otras personas a venir a la Iglesia .
# Translation:	Fourth , please others come to come to come unto the Church .
# Target:		Fourth — invite others to come to church .
#
# Spanish:	Ellos nos ayudan a llegar a salvo a nuestro destino final .
# Translation:	They help us become safe to return to our journey .
# Target:		They help us arrive safely to our final destination .
#
# Spanish:	Es un poder espiritual que se administra según la ley celestial .
# Translation:	It is a spiritual power that is essential .
# Target:		It is a spiritual power that operates on heavenly law .
#
# Spanish:	Tales mujeres me han bendecido a lo largo de la vida .
# Translation:	Such women have blessed me .
# Target:		Throughout my life , I have been blessed by such women .
#
# Spanish:	En mi época no había líneas <unk> que impedían el paso .
# Translation:	In my time I had not forgotten that the tragic step .
# Target:		In our day there were no power lines to prevent access .
#
# Spanish:	Han sido inspirados en cuanto a lo que compartirán con nosotros .
# Translation:	They have been inspired to what we find ourselves .
# Target:		They have been inspired concerning that which they will share with us .
#
# Spanish:	¿ <unk> todos los libros canónicos , incluso el Antiguo Testamento ?
# Translation:	Do all we all have the books , including the Old Testament ?
# Target:		Do you use all of the standard works , including the Old Testament ?
#
# Spanish:	En muchas sociedades del mundo , parece que todo es <unk> .
# Translation:	In many societies , it seems that all is to be forgiven .
# Target:		In so many societies around the world , everything seems to be disposable .
#
# Spanish:	Pronto la llevarían a un hospital y recibiría ayuda para recuperarse .
# Translation:	She would have a hospital and sought to bless him .
# Target:		She would soon be taken to a hospital and helped on her way to recovery .
#
# Spanish:	Este es el equivalente en las Escrituras de considerar el derecho frustrado .
# Translation:	This is the scriptures consider the right scriptures .
# Target:		This is the scriptural equivalent of disgruntled entitlement .
#
# Spanish:	Por consiguiente , a todos se les invita a venir al Señor .
# Translation:	Therefore , all of all are invited to come unto the Lord .
# Target:		Accordingly , all are invited to come to the Lord .
#
# Spanish:	Órgano solo ( sin <unk> , gozo de los anhelos del hombre "
# Translation:	Another .
# Target:		Organ solo ( without <unk> , Joy of Man ’s Desiring "
#
# Spanish:	Hace poco , hablé con una joven Laurel de los Estados Unidos .
# Translation:	I recently recently recently spoke of a young man .
# Target:		Recently , I spoke with a Laurel from the United States .
#
# Spanish:	Quentin L. Cook , Liahona , mayo de 2014 , pág. 47 .
# Translation:	Quentin L. Cook , Ensign or Liahona , May 2014 , 47 .
# Target:		Quentin L. Cook , Ensign or Liahona , May 2014 , 47 .
#
# Spanish:	Podemos llegar a ser hombres y mujeres “ de sano entendimiento ” .
# Translation:	We can become men and women of knowledge . ”
# Target:		We can become men and women “ of a sound understanding . ”
#
# Spanish:	En tres semanas todo el mundo cristiano celebrará la Pascua de Resurrección .
# Translation:	In three weeks the world the world placed the Sabbath .
# Target:		In three weeks ’ time the entire Christian world will be celebrating Easter .
#
# Spanish:	La obra misional más grande que realicemos será en nuestro propio hogar .
# Translation:	The missionary work that you will be in our own homes .
# Target:		The greatest missionary work we will ever do will be in our homes .
#
# Spanish:	El Señor no lo hizo fácil , pero sí lo hizo posible .
# Translation:	The Lord did not do it easy , but He did .
# Target:		The Lord did not make it easy , but He did make it possible .
#
# Spanish:	Él se casó con Emily Keep en <unk> y tuvieron ocho hijos .
# Translation:	He married married with Emily and eight children .
# Target:		He married Emily Keep in <unk> , and they became the parents of eight children .
#
# Spanish:	Todos hemos tenido o tendremos momentos de grandes decisiones en la vida .
# Translation:	We all have had a great moments of great choices in life .
# Target:		All of us have experienced or will yet experience moments of great decision in our lives .
#
# Spanish:	Véase la carta de la Primera Presidencia del 21 de abril de 2011 .
# Translation:	See First Presidency ’s letter , Apr. 21 .
# Target:		See First Presidency letter , Apr. 21 , 2011 .
#
# Spanish:	Al igual que para aprender otro idioma , se requiere práctica y empeño .
# Translation:	Like another language , is necessary to learn and effort .
# Target:		Like learning a foreign language , it takes practice and effort .
#
# Spanish:	José declaró que el Libro de Mormón estaba escrito sobre planchas de oro .
# Translation:	Joseph Smith declared that the Book of Mormon was written on the plates .
# Target:		Joseph claimed that the Book of Mormon was written on gold plates .
#
# Spanish:	Y le damos las gracias por su vida de servicio ejemplar y devoto .
# Translation:	And we thank you for your life and love .
# Target:		And we thank you for your lifetime of exemplary and dedicated service .
#
# Spanish:	El pronóstico fue devastador : le quedaban sólo unas pocas semanas de vida .
# Translation:	The final was the same few weeks ago , I had just a few weeks ago .
# Target:		The prognosis was devastating — he had just a few weeks to live .
#
# Spanish:	Gordon B. Hinckley , “ ¿ No es acaso la verdad ? ” ,
# Translation:	Gordon B. Hinckley , “ Is n’t the truth ? ”
# Target:		Gordon B. Hinckley , “ It ’s True , Is n’t It ? ”
#
# Spanish:	El Señor ha dado el modelo para enfrentar los desafíos de este tipo .
# Translation:	The Lord has given the pattern for challenges .
# Target:		A pattern for coping with such a challenge has been given by the Lord .
#
# Spanish:	Su compasión infinita puede ayudarnos a hallar nuestro camino , verdad y vida .
# Translation:	His compassion can help us find our path , truth , and life .
# Target:		His infinite compassion can help us find our way , truth , and life .
#
# Spanish:	Permítanme sugerir tres maneras de aumentar nuestro conocimiento y confianza en el Salvador .
# Translation:	Let me suggest three ways our knowledge and trust in the Savior .
# Target:		May I suggest three ways to increase our knowledge of and trust in the Savior .
#
# Spanish:	Estas palabras del Salvador cobraron una importancia más profunda para mí como padre :
# Translation:	These words did in the Savior ’s most important importance :
# Target:		These words of the Savior took on a much deeper meaning to me as a father :
#
# Spanish:	El fin del mundo vendrá antes de que llegue hasta donde debo ” .
# Translation:	The end of the world will come before it . ”
# Target:		The end of the world is going to come before I get to where I should be . ”
#
# Spanish:	El mundo exclama en <unk> : “ ¿ Cómo puedes exigir tanto ? ” .
# Translation:	The world would be followed , “ How can you be born ? ”
# Target:		The world <unk> , how can you ask so much ?
#
# Spanish:	Estoy agradecido por los ejemplos de los fieles poseedores del sacerdocio de todas partes .
# Translation:	I am grateful for the examples of faithful priesthood holders everywhere .
# Target:		I am grateful for the examples of faithful priesthood holders everywhere .
#
# Spanish:	Los números de página que aparecen a continuación indican la primera página del discurso .
# Translation:	The page of page who are found in the first page of the talk .
# Target:		The page numbers listed below indicate the first page of the talk .
#
# Spanish:	Incluso podríamos preguntarnos : ¿ Por qué estamos hoy aquí , en esta reunión ?
# Translation:	We might wonder , what we are here today , here in this meeting ?
# Target:		We could even ask , why are we here at this meeting today ?
#
# Spanish:	Él posee las llaves y puede ayudarlos a lo largo del camino del arrepentimiento .
# Translation:	He holds the keys and can help them .
# Target:		He holds the keys and can help you along the pathway of repentance .
#
# Spanish:	“ no busca lo suyo , no se irrita , no piensa el mal ;
# Translation:	“ Do not do not be forgiven , do n’t do anything .
# Target:		“ <unk> not her own , is not easily provoked , thinketh no evil ;
#
# Spanish:	Veían las bendiciones de Nefi como “ agravios ” que se <unk> contra ellos .
# Translation:	They saw the blessings of Nephi as “ they were forgiven .
# Target:		They seemed to view Nephi ’s blessings as “ wrongs ” committed against them .
#
# Spanish:	El Espíritu Santo es nuestro consolador , revelador , maestro , testigo y guía .
# Translation:	The Holy Ghost is our privilege , seer , and revelator .
# Target:		The Holy Ghost is our comforter , revelator , teacher , <unk> , and guide .
#
# Spanish:	En realidad , ¡ ninguno de nosotros jamás dejará de ser hijo de Dios !
# Translation:	In reality , none of us will never leave God !
# Target:		In truth , not one of us can ever stop being a child of God !
#
# Spanish:	<unk> a convertirte como consecuencia de … esfuerzos rectos por seguir al Señor ” .
# Translation:	They will be able to make the righteous efforts of the Lord . ”
# Target:		You become converted as a result of … righteous efforts to follow the Savior . ”
#
# Spanish:	Nos sentamos en las piedras , <unk> la situación e <unk> un nuevo plan .
# Translation:	We looked at the top , and they moved to a new plan .
# Target:		We sat down on the rocks , assessed our situation , and devised a new plan .
#
#
# Spanish:	Si <unk> con sinceridad que estamos tratando de mejorar , no somos hipócritas , somos humanos .
# Translation:	If we are able to focus on trying , we are not afraid .
# Target:		If we admit that honestly and are trying to improve , we are not hypocrites ; we are human .
#
# Spanish:	Ella me miró ; casi podía ver su mente dar vueltas mientras esperaba ansiosamente su respuesta .
# Translation:	She looked at me . I could see her mind as she would be able to leave her answer .
# Target:		She looked at me ; I could almost see the wheels turning in her little mind as I waited anxiously for her response .
#
# Spanish:	La obra de la traducción <unk> rápido una vez que Oliver se comprometió a ser el escribiente .
# Translation:	The work of the translation would be a time to be baptized .
# Target:		The work of translation progressed rapidly once Oliver committed to act as scribe .
#
# Spanish:	Cada una de ustedes se halla en un momento particular de su trayectoria a la vida eterna .
# Translation:	Each of you are found in a time of your life to eternal life .
# Target:		Each of you is in a unique place in your journey to eternal life .
#
# Spanish:	Él ha proporcionado un escape para todos los que son víctimas de los errores de los demás .
# Translation:	He has provided a consecrated for all of others who are changed .
# Target:		He has provided an escape for all who fall victim to the misdeeds of others .
#
# Spanish:	Cuando se encontró con el Salvador , preguntó : “ ¿ Qué más me falta ? ” .
# Translation:	When I found with the Savior , asked , “ What lack me ? ”
# Target:		When he met the Savior , he asked , “ What lack I yet ? ”
#
# Spanish:	“ Y el segundo es semejante a éste : Amarás a tu prójimo como a ti mismo .
# Translation:	“ And the second is like this is ye shall love thy neighbour as thyself .
# Target:		“ And the second is like unto it , Thou shalt love thy neighbour as thyself .
#
# Spanish:	Quiero concluir con el relato de una experiencia reciente que tuvo un impacto en cientos de personas .
# Translation:	I want to close with the story of a recent experience that had a impact in hundreds of people .
# Target:		I should like to conclude by relating one recent experience which had an impact on hundreds .
#
# Spanish:	Cada creyente necesita una confirmación espiritual de la misión divina y del carácter del profeta José Smith .
# Translation:	Each kind spiritual confirmation and personal testimony of the divine character and character .
# Target:		Each believer needs a spiritual confirmation of the divine mission and character of the Prophet Joseph Smith .
#
# Spanish:	Vivamos la verdad , a fin de que merezcamos todo lo que el Padre tiene para nosotros .
# Translation:	Let us find truth , that we will ever be able to have the Father ’s Father has for us .
# Target:		Let us live the truth , that we might merit all that the Father has for us .
#
# Spanish:	El presidente Thomas S. Monson , quien preside la conferencia , ha pedido que dirija esta sesión .
# Translation:	President Thomas S. Monson , who presides at the conference , has asked this session .
# Target:		President Thomas S. Monson , who presides at the conference , has asked that I conduct this session .
#
# Spanish:	El joven respondió : “ Aquí no hay oro ; me voy a volver a casa ” .
# Translation:	The young man replied , “ I am not afraid to return home . ”
# Target:		The young man replied , “ There ’s no gold here . I ’m going back home . ”
#
# Spanish:	<unk> lo que sabes de forma que tus amigos se sientan alentados a desear ser espiritualmente fortalecidos .
# Translation:	They will recognize what you know your friends are to be spiritually strengthened .
# Target:		You will share what you know in a way that encourages your friends to want to be strengthened spiritually .
#
# Spanish:	El rey les advirtió que si no cumplían , serían <unk> en un horno de fuego ardiente .
# Translation:	The king warned them that if they would not be a fire of fire .
# Target:		The king warned them that they would be cast into a burning fiery furnace if they did n’t comply .
#
# Spanish:	Si no sabes a dónde quieres ir , entonces tampoco importa mucho el camino que tomes ” .
# Translation:	If you do not know where you want to go , then your way . ”
# Target:		If you do not know where you want to go , it does n’t matter which path you take . ”
#
# Spanish:	Fernando sirve actualmente como obispo por tercera vez y continúa rescatando , tal como él fue rescatado .
# Translation:	Fernando serves as a bishop for the third , and it was as he was called .
# Target:		Fernando is now serving as bishop for the third time , and he continues to rescue , just like he was rescued .
#
# Spanish:	Me estaban guiando y enseñándome la senda a seguir , especialmente cuando tenía que hacer algo difícil .
# Translation:	I were able to study and apply the path to follow , especially when I had to do something difficult .
# Target:		They were leading me , guiding me , and even walking beside me to help me find the way — especially when I had to do something difficult .
#
# Spanish:	Además , la revelación personal y las experiencias espirituales están íntimamente relacionadas con el programa de maestras visitantes .
# Translation:	In addition , personal revelation and spiritual experiences are used to build the program .
# Target:		Also , personal revelation and spiritual experiences are closely connected with visiting teaching .
#
# Spanish:	¿ Cómo podemos nosotros , como aconsejó Pablo : “ dejar a un lado todo peso ” ? .
# Translation:	How can we , as Paul counseled , “ Oh , a weight ? ”
# Target:		How can we , as Paul counseled , “ lay aside every weight ” ?
#
# Spanish:	Pedro nos <unk> a añadir " al conocimiento , templanza ; y a la templanza , paciencia " .
# Translation:	Peter will rise to us " seek the knowledge , patience , patience , and patience . "
# Target:		Peter exhorts us to add " to knowledge temperance ; and to temperance patience . "
#
# Spanish:	Allí encontró al rey Limhi y a su pueblo , que estaban bajo el cautiverio de los lamanitas .
# Translation:	There were found the king and his people , who were under the bondage of the Lamanites .
# Target:		There he found King Limhi and his people , who were in bondage to the Lamanites .
#
# Spanish:	En la Biblia leemos acerca de la visita de Cristo a la casa de Simón , el fariseo .
# Translation:	In the Bible we read about the visit of Christ , the house of Simon .
# Target:		In the Bible we read of Christ ’s visit to the home of Simon the Pharisee .
#
# Spanish:	De esas dos experiencias comunes y corrientes con la luz podemos aprender mucho acerca del espíritu de revelación .
# Translation:	We have two different experiences and most of the light we can learn about the spirit of revelation .
# Target:		From these two ordinary experiences with light , we can learn much about the spirit of revelation .
#
# Spanish:	Nadie dispondría de albedrío ni de libertad de elección , por lo cual no se requeriría ninguna oposición .
# Translation:	Never be a agency of agency , for any of choice , for no opposition is no opposition .
# Target:		There would be no agency or choice by anyone and , therefore , no need for opposition .
#
# Spanish:	Cuando se trata de la verdad espiritual , ¿ cómo podemos saber que estamos en el camino correcto ?
# Translation:	When we are the spiritual truth , how we can know that we are in the right road ?
# Target:		When it comes to spiritual truth , how can we know that we are on the right path ?
#
# Spanish:	Neil L. Andersen , “ Sabes lo suficiente ” , Liahona , noviembre de 2008 , pág. 13 .
# Translation:	Neil L. Andersen , “ Let me not enough , ” Ensign or Liahona , Nov. 2008 , 13 .
# Target:		Neil L. Andersen , “ You Know Enough , ” Ensign or Liahona , Nov. 2008 , 14 .
#
# Spanish:	Y en segundo lugar , es describir parte de lo que aún se espera de su servicio <unk> .
# Translation:	And in the second , it is to describe it .
